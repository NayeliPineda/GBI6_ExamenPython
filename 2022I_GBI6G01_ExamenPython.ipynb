# %% [markdown]
# <img src="https://www.ikiam.edu.ec/img/logo-ikiam-grey.png" width=300 height=200 />
#
# # EXAMEN PARCIAL PYTHON
#
#
# ## GBI6-2021II: BIOINFORMÁTICA
#
# **Pineda, Nayeli Mariuxi**
#
# **05-08-2022**

# %% [markdown]
# <font color='red'>Color de texto</font>

# %% [markdown]
# ### REQUERIMIENTOS PARA EL EXAMEN
#
# Utilice de preferencia ```Jupyter``` de Anaconda, dado que tienen que hacer un control de cambios en cada pregunta.
#
# Para este examen se requiere dos documentos:
#
# 1. Archivo ```miningscience.py``` donde tendrá dos funciones:
#
# 2. Archivo ```2022I_GBI6_ExamenPython``` donde se llamará las funciones y se obtendrá resultados.

# %% [markdown]
# ## Ejercicio 0 [0.5 puntos]
# Realice cambios al cuaderno de jupyter:
# - Agregue el logo de la Universidad
# - Coloque sus datos personales
# - Escriba una **tabla** con las características de su computador
#
#
# ## GBI6-2021II: BIOINFORMÁTICA
# - Datos personales:
#
# **Pineda, Nayeli Mariuxi**
#
# <font color='purple'>**Tabla 1. Características del computador**</font>
#
# <table>
#   <tr>
#     <th>Edición de Windows</th>
#     <th>Procesador</th>
#     <th>Memoria instalada(RAM)</th>
#     <th>Tipo de sistema</th>
#     <th>Nombre del equipo</th>
#   </tr>
#   <tr>
#     <td>Windows 10 Home</td>
#     <td>Intel(R) Core(TM) i3-7020U CPU @ 2.30GHz 2.30 GHz</td>
#     <td>4,00 GB (3,88 GB utilizzable)</td>
#     <td>Sistema operativo de 64 bits, procesador x64</td>
#     <td>DESKTOP-5CO3D9H</td>
#   </tr>
# </table>

# %% [markdown]
# ## Ejercicio 1 [2 puntos]
# Cree el archivo ```miningscience.py``` con las siguientes dos funciones:
#
# i. ```download_pubmed```: para descargar la data de PubMed utilizando el **ENTREZ** de Biopython. El parámetro de entrada para la función es el ```keyword```.
#
# ii. ```science_plots```: la función debe
#
# - utilizar como argumento de entrada la data descargada por ```download_pubmed```
# - ordenar los conteos de autores por país en orden ascedente y
# - seleccionar los cinco más abundantes. Con esta selección debe graficar un ```pie_plot```. Como guía para el conteo por países puede usar el ejemplo de [MapOfScience](https://github.com/CSB-book/CSB/blob/master/regex/solutions/MapOfScience_solution.ipynb).
#
# iii *Cree un docstring para cada función.*
#
# Luego de crear las funciones, cargue el módulo ```miningscience``` como ```msc``` e **imprima docstring de cada función**.

# %%
# Escriba aquí su código para el ejercicio 1

import miningscience_g01 as msc
help (msc.download_pubmed)
help (msc.science_plots)
# Out:
# Help on function download_pubmed in module miningscience_g01:
#
# download_pubmed(keyword)
#     la función download_pubmed permite como ingreso una palabra de búsqueda "palabras clave" de artículos en pubmed
#
# Help on function science_plots in module miningscience_g01:
#
# science_plots(archivo)
#     la función science_plots permite ordenar los conteos de autores por país en orden ascedente
#     y seleccionar los cinco más abundantes en función de una palabra de búsqueda "palabras clave" de artículos en pubmed.

# %% [markdown]
# ## Ejercicio 2 [2 puntos]
#
#
# Utilice dos veces la función ```download_pubmed``` para:
#
# - Descargar la data, utilizando los keyword de su preferencia.
# - Guardar el archivo descargado en la carpeta ```data```.
#
# Para cada corrida, imprima lo siguiente:
#
# ```python
# 'El número artículos para KEYWORD es: XX' # Que se cargue con inserción de texto o valor que correspondea KEYWORD y XX
# ```

# %%
# Escriba aquí su código para el ejercicio 2
p1="bacteria"
busquedaA = msc.download_pubmed(p1)
print ('El número artículos para ', (p1), ' es: ', len (busquedaA))
with open ("Data/Bacteria.txt","w") as txt:
    txt.write(busquedaA)
# Out:
# El número artículos para  bacteria  es:  2415939

# %%
p2="animal"
busquedaB = msc.download_pubmed(p2)
print ('El número artículos para ', (p2), ' es: ', len (busquedaB))
with open ("Data/animal.txt","w") as txt:
    txt.write(busquedaB)
# Out:
# El número artículos para  animal  es:  2336063

# %% [markdown]
# ## Ejercicio 3 [1.5 puntos]
#
# Utilice dos veces la función ```science_plots``` para:
#
# - Visualizar un pie_plot para cada data descargada en el ejercicio 2.
# - Guardar los pie_plot en la carpeta ```img```

# %%
# Escriba aquí su código para el ejercicio 3
gy=msc.science_plots(busquedaA)
gy
# Out:
#     Country  num_auth    Porcent
# 13    China      1163  62.729234
# 33    India       233  12.567422
# 17  Germany       178   9.600863
# 21    Spain       158   8.522114
# 38    Japan       122   6.580367

# %%
gx=msc.science_plots(busquedaB)
gx
# Out:
#     Country  num_auth    Porcent
# 10    China      1158  66.820542
# 5    Brazil       174  10.040392
# 34    Japan       144   8.309290
# 20   France       134   7.732256
# 13  Germany       123   7.097519

# %% [markdown]
# ## Ejercicio 4 [1 punto]
#
# **Interprete** los resultados de las figuras del **ejercicio 3**

# %% [markdown]
# #ejericio 3
# .
# En el pie_plot se puede observar los cinco países más abundantes en publicaciones en pubmed de acuerdo a la palabra clave "Bacteria", el primer lugar con 60.99 % se encuentra China, con un 13.43% esta India, con un 8.85% está Francia, con un 8.44 está Canada y por último Japón con un 8.26 %
#
# .# ejercicio 5
# Por otra parte, Gen de enzima elegida: L-lactate dehydrogenase
# En árbol filogenetico fue elaborado a partir de las primeras quince IDs accesion list. Se puede observar que IDs AK157303.1 y XM_021263906 pertenecen a genes que comparten un parentesco debido a una ancestro en común entre ellos. XM_048805915.1 y XM_046456600.1 de igual manera comparten un ancestro en común en el interior 3. Sin embargo se puede observar que estos mismo genes tienen un ancenstro en común con XM_021237964.1 en el interior 5. También se observa que XM_035456120.1 y XM_035440424.1 comparten un ancenstro en común en el interio 1 y en el interior 7 comparten un ancenstro en común con XM_023646520.1 aunque se puede verificar que hay un largo trama de tiempo que los diferencia. Los todos IDs mencionados anteiormente se puede obsrvar en el arbol foligentico que en el interior 8 logran compartir un ancestro en común pero hay un largo espacio de tiempo y una difenrencia que se vera reflejada geneticamente y posiblemente morfologicamente. En cambio, XM_041744590.1 tiene un ancestro en común en el interior 9. Por otro lado, XM_045805409.1 comparte un parentesco con XM_026505126.3 en el interior 12 aunque hay un largo tiempo de diferencia que se podría ver reflejado geneticamente. Por último en el interior 2 se puede observar que XM_043888102.1 y XM_043456963.1 comparten un ancestro en común.
# .

# %% [markdown]
# ## Ejercicio 5 [2 puntos]
#
# Para algún **gen de las enzimas que intervienen en la ruta metabolica de la gluconeogenesis** ([Lista de genes por tipología](https://www.genome.jp/pathway/map00010+C00068)), realice lo siguiente:
#
# 1. Una búsqueda en la página del [NCBI nucleotide](https://www.ncbi.nlm.nih.gov/nucleotide/).
#
# 2. Descargue el ```Accession List``` de su búsqueda y guarde en la carpeta ```data```.
#
# 3. Cargue el ```Accession List``` en este notebook y haga una descarga de las secuencias de los **quince primeros** IDs de la accesión.
#
# 4. Arme un árbol filogenético para los resultados del paso 3.
#
# 5. Guarde su arbol filogénetico en la carpeta ```img```
#
# 5. Interprete el árbol del paso 4.

# %%
# Escriba aquí su código para el ejercicio 6
# Gen de enzima elegida: L-lactate dehydrogenase  

from Bio import Entrez
from Bio import Phylo
from Bio.Phylo.TreeConstruction import DistanceCalculator
from Bio.Phylo.TreeConstruction import DistanceTreeConstructor
from Bio import AlignIO
from Bio import SeqIO
from Bio.Align.Applications import ClustalwCommandline
import os
import matplotlib
import matplotlib.pyplot as plt

with open('data/lactate.seq') as file:
    text = file.read()
text = text.split('\n')
text = ','.join(text[:15])

handle = Entrez.efetch( db="nucleotide", rettype="gb", retmode="text", id = text)
print(handle.url)
records = SeqIO.parse("data/lactate.gb", "genbank") 
count = SeqIO.write(records, "data/lactate.fasta", "fasta") 

clustalw_exe = r"C:\Program Files (x86)\ClustalW2\clustalw2.exe"
clustalw_cline = ClustalwCommandline(clustalw_exe, infile = "data/lactate.fasta")
assert os.path.isfile(clustalw_exe), "Clustal_W executable is missing or not found"
stdout, stderr = clustalw_cline()
print(clustalw_cline)

ClustalAlign = AlignIO.read("data/lactate.aln", "clustal")

with open("data/lactate.aln","r") as aln: 
    alignment = AlignIO.read(aln,"clustal")
    
calculator = DistanceCalculator("identity")
distance_matrix = calculator.get_distance(alignment)

constructor = DistanceTreeConstructor(calculator)
lactate_tree = constructor.build_tree(alignment)
lactate_tree.rooted = True
Phylo.draw(lactate_tree)

fig = plt.figure(figsize=(50, 60), dpi=200) # create figure & set the size 
matplotlib.rc('font', size=12)              # fontsize of the leaf and node labels 
matplotlib.rc('xtick', labelsize=20)       # fontsize of the tick labels
matplotlib.rc('ytick', labelsize=20)       # fontsize of the tick labels
axes = fig.add_subplot(1, 1, 1)
Phylo.draw(lactate_tree, axes=axes)
fig.savefig("img/lactate_tree")
# Out:
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=nucleotide&rettype=gb&retmode=text&id=XM_026505126.3%2CXM_035456120.1%2CXM_035440424.1%2CXM_023646520.1%2CXM_013044968.2%2CXM_045805409.1%2CXM_021237964.1%2CXM_046456600.1%2CXM_043456963.1%2CXM_043888102.1%2CXM_048805915.1%2CXM_041744590.1%2CXM_017657075.2%2CAK157303.1%2CXM_021263906.1&tool=biopython&email=A.N.Other%40example.com
# "C:\Program Files (x86)\ClustalW2\clustalw2.exe" -infile=data/lactate.fasta

# %% [markdown]
# **Escriba aquí la interpretación del árbol**
# Gen de enzima elegida: L-lactate dehydrogenase
# En árbol filogenetico fue elaborado a partir de las primeras quince IDs accesion list. Se puede observar que IDs AK157303.1 y XM_021263906 pertenecen a genes que comparten un parentesco debido a una ancestro en común entre ellos. XM_048805915.1 y XM_046456600.1 de igual manera comparten un ancestro en común en el interior 3. Sin embargo se puede observar que estos mismo genes tienen un ancenstro en común con XM_021237964.1 en el interior 5. También se observa que XM_035456120.1 y XM_035440424.1 comparten un ancenstro en común en el interio 1 y en el interior 7 comparten un ancenstro en común con XM_023646520.1 aunque se puede verificar que hay un largo trama de tiempo que los diferencia. Los todos IDs mencionados anteiormente se puede obsrvar en el arbol foligentico que en el interior 8 logran compartir un ancestro en común pero hay un largo espacio de tiempo y una difenrencia que se vera reflejada geneticamente y posiblemente morfologicamente. En cambio, XM_041744590.1 tiene un ancestro en común en el interior 9. Por otro lado, XM_045805409.1 comparte un parentesco con XM_026505126.3 en el interior 12 aunque hay un largo tiempo de diferencia que se podría ver reflejado geneticamente. Por último en el interior 2 se puede observar que XM_043888102.1 y XM_043456963.1 comparten un ancestro en común.

# %% [markdown]
# ## Ejercicio 6 [1 punto]
#
#
# 1. Cree en GitHub un repositorio de nombre ```GBI6_ExamenPython```.
# 2. Cree un archivo ```Readme.md``` que debe tener lo siguiente:
# - Datos personales
# - Características del computador
# - Versión de Python/Anaconda y de cada uno de los módulos/paquetes y utilizados
# - Explicación de la data utilizada
# - Un diagrama de procesos del módulo ```miningscience```
# 3. Asegurarse que su repositorio tiene las carpetas ```data``` e ```img``` con los archivos que ha ido guardando en las preguntas anteriores.
# 4. Realice al menos 1 control de la versión (commits) por cada ejercicio (del 1 al 5), con un mensaje que inicie como:
#
# ```sh
# Carlitos Alimaña ha realizado el ejercicio 1
# ```
# ```sh
# Carlitos Alimaña ha realizado el ejercicio 2
# ```
# ```sh
# ...
# ```
